# %% [markdown]
# <a href="https://colab.research.google.com/github/aaryan180207/python-experiments/blob/main/experiment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First Python Program/ String
print("hello , welcoe to python program")
# Out:
# hello , welcoe to python program

# %% [markdown]
# Name-Aaryan Jhamtani
# PRN-25070123005
# Branch-ENTC
# Batch-A1

# %%
print("hello"); print("barcelona beat real madrid"); print("india beat new zealand")
# Out:
# hello
# barcelona beat real madrid
# india beat new zealand

# %%
print("hello", end=" ")
print("barcelona beat real madrid")
print("india beat new zealand")
# Out:
# hello barcelona beat real madrid
# india beat new zealand

# %%
print(5)
# Out:
# 5

# %%
x,y,z=1,2,3
print(x,y,z)
# Out:
# 1 2 3

# %%
a=10
b=7
print("Subtraction=",a-b)
# Out:
# Subtraction= 3

# %%
x=10
y=3.14
z="chahek"
flag=True
C=3+2j
print(type(x))
print(type(y))
print(type(z))
print(type(flag))
print(type(C))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
name=input("enter your name")
print(name)
# Out:
# enter your namearyan
# aryan

# %%
a =int(input("enter first number"))
b =int(input("enter second number"))
print("subtraction=", a-b)

# %%
m1=int(input("enter a number"))
m2=int(input("enter a number"))
m3=int(input("enter a number"))
m4=int(input("enter a number"))
m5=int(input("enter a number"))
print("addition=", m1+m2+m3+m4+m5)
print("divsion=", m1+m2+m3+m4+m5/5)

# %%
a=float(input("enter a number"))
b=float(input("enter a number"))
print("area of rectangle=", a*b)
# Out:
# enter a number7.4
# enter a number8.6
# area of rectangle= 63.64

# %%
r=float(input("enter a number"))
print("area of circle=", 3.14*r*r)
# Out:
# enter a number7.4
# area of circle= 171.9464

# %%
print(3**3)
# Out:
# 27

# %%
print((3,4,5)+(6,7,8))
# Out:
# (3, 4, 5, 6, 7, 8)
